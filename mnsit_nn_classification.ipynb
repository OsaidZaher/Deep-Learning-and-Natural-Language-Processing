# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
(X_train_full, y_train_full), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
X_train_full.shape
X_train_full.dtype
# Out:
# dtype('uint8')

# %%
X_val, X_train = X_train_full[:5000]/255., X_train_full[5000:]/255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test/255.

# %%
plt.imshow(X_train[0], cmap="binary")
plt.axis('off')
plt.show()

# %%
X_val.shape, X_train.shape, X_test.shape
# Out:
# ((5000, 28, 28), (55000, 28, 28), (10000, 28, 28))

# %%
n_rows = 4
n_cols = 10
plt.figure(figsize=(n_cols * 1.2, n_rows * 1.2))
for row in range(n_rows):
    for col in range(n_cols):
        index = n_cols * row + col
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(X_train[index], cmap="binary", interpolation="nearest")
        plt.axis('off')
        plt.title(y_train[index], fontsize=12)
plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %%
K = tf.keras.backend
class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_batch_end(self, batch, logs=None):
        lr= self.model.optimizer.learning_rate.numpy()*self.factor
        self.model.optimizer.learning_rate = lr
        self.rates.append(lr)
        self.losses.append(logs["loss"])

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")

])
# Out:
# c:\Users\bigma\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-3)
model.compile(loss="sparse_categorical_crossentropy",optimizer=optimizer, metrics=["accuracy"]) 
expon_lr = ExponentialLearningRate(factor=1.005)

# %%
history = model.fit(X_train, y_train, epochs=1, validation_data=(X_val, y_valid), callbacks=[expon_lr])
# Out:
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5382 - loss: nan - val_accuracy: 0.0958 - val_loss: nan

# %%
plt.plot(expon_lr.rates, expon_lr.losses)
plt.gca().set_xscale('log')
plt.hlines(min(expon_lr.losses), min(expon_lr.rates), max(expon_lr.rates))
plt.axis([min(expon_lr.rates), max(expon_lr.rates), 0, expon_lr.losses[0]])
plt.grid()
plt.xlabel("Learning rate")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
tf.keras.backend.clear_session()
np.random.seed(42)  
tf.random.set_seed(42)
# Out:
# WARNING:tensorflow:From c:\Users\bigma\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=3e-1)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
run_index = 1 # increment this at every run
run_logdir = Path() / "my_mnist_logs" / "run_{:03d}".format(run_index)
run_logdir
# Out:
# WindowsPath('my_mnist_logs/run_001')

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20)
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_mnist_model.keras", save_best_only=True)
tensorboard_cb = tf.keras.callbacks.TensorBoard(run_logdir)

history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_val, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb, tensorboard_cb])
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8685 - loss: 0.4090 - val_accuracy: 0.9700 - val_loss: 0.1013
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9702 - loss: 0.0998 - val_accuracy: 0.9744 - val_loss: 0.0849
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9802 - loss: 0.0628 - val_accuracy: 0.9756 - val_loss: 0.0834
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9873 - loss: 0.0421 - val_accuracy: 0.9790 - val_loss: 0.0798
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9891 - loss: 0.0347 - val_accuracy: 0.9792 - val_loss: 0.0823
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9919 - loss: 0.0258 - val_accuracy: 0.9800 - val_loss: 0.0840
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9940 - loss: 0.0183 - val_accuracy: 0.9776 - val_loss: 0.1043
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9938 - loss: 0.0195 - val_accuracy: 0.9790 - val_loss: 0.0923
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9949 - loss: 0.0146 - val_accuracy: 0.9808 - val_loss: 0.1094
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9939 - loss: 0.0178 - val_accuracy: 0.9786 - val_loss: 0.1065

# %%
model = tf.keras.models.load_model("my_mnist_model.keras")
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9704 - loss: 0.1016
# [0.08082236349582672, 0.9757999777793884]

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 21984), started 2 days, 10:16:34 ago. (Use '!kill 21984' to kill it.)
#       <iframe id="tensorboard-frame-bee3ae2ae9419bee" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bee3ae2ae9419bee");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
